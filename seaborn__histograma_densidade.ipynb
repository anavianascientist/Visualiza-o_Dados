# %% [markdown]
# <a href="https://colab.research.google.com/github/anavianascientist/Visualiza-o_Dados/blob/master/seaborn__histograma_densidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Histograma com densidade e seaborn

# %%
# Importação das bibliotecas
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt
import io
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Carregamento da base de dados
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf70b0d1-8b1a-4876-ba9f-183441702cf0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf70b0d1-8b1a-4876-ba9f-183441702cf0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trees.csv to trees.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['trees.csv']))

df.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Histograma com 10 divisões (bins) e com gráfico de densidade
sea.distplot(df.Volume, bins = 10, axlabel = 'Volume').set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
# Carregamento de outra base de dados
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb6ed3e8-bafb-466d-8648-c16c7b2e2bd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb6ed3e8-bafb-466d-8648-c16c7b2e2bd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chicken.csv to chicken.csv

# %%
df1 = pd.read_csv(io.BytesIO(uploaded['chicken.csv']))

df1.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
df1.shape
# Out:
# (71, 2)

# %%
# Criação de novo dataframe agrupando o atributo 'feed'
agrupado = df1.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
# Novo dataframe somente para testar os filtros do pandas
teste = df1.loc[df1['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
# Histrograma considerando somente o valor 'horsebean'
sea.distplot(df1.loc[df1['feed'] == 'horsebean'].weight, hist = False).set_title('horsebean')
# Out:
# Text(0.5, 1.0, 'horsebean')

# %%
# Histrograma considerando somente o valor 'casein'
sea.distplot(df1.loc[df1['feed'] == 'casein'].weight).set_title('casein')
# Out:
# Text(0.5, 1.0, 'casein')

# %%
# Histrograma considerando somente o valor 'linseed'
sea.distplot(df1.loc[df1['feed'] == 'linseed'].weight).set_title('linseed')
# Out:
# Text(0.5, 1.0, 'linseed')

# %%
# Histrograma considerando somente o valor 'meatmeal'
sea.distplot(df1.loc[df1['feed'] == 'meatmeal'].weight).set_title('meatmeal')
# Out:
# Text(0.5, 1.0, 'meatmeal')

# %%
# Histrograma considerando somente o valor 'soybean'
sea.distplot(df1.loc[df1['feed'] == 'soybean'].weight).set_title('soybean')
# Out:
# Text(0.5, 1.0, 'soybean')

# %%
# Histrograma considerando somente o valor 'sunflower'
sea.distplot(df1.loc[df1['feed'] == 'sunflower'].weight).set_title('sunflower')
# Out:
# Text(0.5, 1.0, 'sunflower')

# %%
#impresssão em gráfico 2 x 3
plt.figure()
plt.subplot(3,2,1)
sea.distplot(df1.loc[df1['feed'] == 'horsebean'].weight, hist = False).set_title('horsebean')
plt.subplot(3,2,2)
sea.distplot(df1.loc[df1['feed'] == 'casein'].weight).set_title('casein')
plt.subplot(3,2,3)
sea.distplot(df1.loc[df1['feed'] == 'linseed'].weight).set_title('linseed')
plt.subplot(3,2,4)
sea.distplot(df1.loc[df1['feed'] == 'meatmeal'].weight).set_title('meatmeal')
plt.subplot(3,2,5)
sea.distplot(df1.loc[df1['feed'] == 'soybean'].weight).set_title('soybean')
plt.subplot(3,2,6)
sea.distplot(df1.loc[df1['feed'] == 'sunflower'].weight).set_title('sunflower')
#ajusta o layout para não haver sobreposição
plt.tight_layout()
